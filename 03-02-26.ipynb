# %% [markdown]
# import numpy as np
# import pandas as pd
# file=r"C:\Users\Dell\Desktop\new_course\Data files\Part 3 - Regression using Python\House_Price.csv"
# df=pd.read_csv(file,header=0)
# print(df)

# %%
df.head(12)
index_price=df.set_index(['price'])
print(index_price)
# Out:
#        crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  dist3  \
# price
# 24.0      0.00632       32.31     0.538     6.575  65.2   4.35   3.81   4.18
# 21.6      0.02731       37.07     0.469     6.421  78.9   4.99   4.70   5.12
# 34.7      0.02729       37.07     0.469     7.185  61.1   5.03   4.86   5.01
# 33.4      0.03237       32.18     0.458     6.998  45.8   6.21   5.93   6.16
# 36.2      0.06905       32.18     0.458     7.147  54.2   6.16   5.86   6.37
# ...           ...         ...       ...       ...   ...    ...    ...    ...
# 22.4      0.06263       41.93     0.573     6.593  69.1   2.64   2.45   2.76
# 20.6      0.04527       41.93     0.573     6.120  76.7   2.44   2.11   2.46
# 23.9      0.06076       41.93     0.573     6.976  91.0   2.34   2.06   2.29
# 22.0      0.10959       41.93     0.573     6.794  89.3   2.54   2.31   2.40
# 19.0      0.04741       41.93     0.573     6.030  80.8   2.72   2.24   2.64
#
# ...

# %% [markdown]
# df.loc[1]
# df.iloc[20]

# %% [markdown]
# df.loc[(df['crime_rate']>0.05) & (df['age']>66)]

# %%
mean_price=df['age'].mean()
print(mean_price)
# Out:
# 68.57490118577076

# %% [markdown]
# df[['age','crime_rate','dist3']]

# %% [markdown]
# df['crime_rate'].astype(int)
# print(df['crime_rate'])
# df['crime_rate'].dtype

# %%
dataf=pd.DataFrame(df[['crime_rate','age']])
print(dataf)

datak=pd.DataFrame(df[['crime_rate','airport']])
print(datak)
# Out:
#      crime_rate   age
# 0       0.00632  65.2
# 1       0.02731  78.9
# 2       0.02729  61.1
# 3       0.03237  45.8
# 4       0.06905  54.2
# ..          ...   ...
# 501     0.06263  69.1
# 502     0.04527  76.7
# 503     0.06076  91.0
# 504     0.10959  89.3
# 505     0.04741  80.8
#
# [506 rows x 2 columns]
#      crime_rate airport
# 0       0.00632     YES
# 1       0.02731      NO
# 2       0.02729      NO
# 3       0.03237     YES
# 4       0.06905      NO
# ..          ...     ...
# 501     0.06263      NO
# 502     0.04527     YES
# 503     0.06076      NO
# 504     0.10959     YES
# 505     0.04741     YES
#
# [506 rows x 2 columns]

# %%
pd.merge(datak, dataf, on='crime_rate', how='inner').set_index('crime_rate')
# Out:
#            airport   age
# crime_rate
# 0.00632        YES  65.2
# 0.02731         NO  78.9
# 0.02729         NO  61.1
# 0.03237        YES  45.8
# 0.06905         NO  54.2
# ...            ...   ...
# 0.06263         NO  69.1
# 0.04527        YES  76.7
# 0.06076         NO  91.0
# 0.10959        YES  89.3
# 0.04741        YES  80.8
#
# [510 rows x 2 columns]

# %% [markdown]
# grp=datak.groupby(by='crime_rate').agg(['mean'])

# %%
pwd
# Out:
# 'C:\\Users\\Dell'

# %%
df['airport'][0]=='NO'
# Out:
# False

# %%
h={'name':['bolu','shane']}
h.update({'name':['kolu','shane']})
print(h)
h.values()
# Out:
# {'name': ['kolu', 'shane']}
# dict_values([['kolu', 'shane']])

# %%
import seaborn as sns
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %%
sns.jointplot(x='n_hot_rooms',y='price',data=df)
sns.countplot(x='waterbody',data=df)
# Out:
#   Cell In[143], line 3
#     sns.color_palette(data='waterbody','River'=red)
#                                        ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %% [markdown]
# help(df.plot)

# %% [markdown]
# df.plot(x='waterbody',y='price',kind='line')

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    3.613524   41.136779    0.554695    6.284634   68.574901
# std      9.182176    8.601545    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006320   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.082045   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.256510   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    3.677083   48.100000    0.624000    6.623500   94.075000
# max     50.000000   88.976200   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# ...

# %%
import numpy as np
q1=df['rainfall'].quantile(0.25)
q2=df['rainfall'].quantile(0.75)
iqr=q2-q1
lower_limit=q1-1.5*iqr
upper_limit=q2+1.5*iqr
new_df=df[(df['rainfall']>=lower_limit) & (df['rainfall']<=upper_limit)]
new_df
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0     24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1     21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2     34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3     33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4     36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
# ..     ...         ...         ...       ...       ...   ...    ...    ...
# 501   22.4     0.06263       41.93     0.573     6.593  69.1   2.64   2.45
# 502   20.6     0.04527       41.93     0.573     6.120  76.7   2.44   2.11
# 503   23.9     0.06076       41.93     0.573     6.976  91.0   2.34   2.06
# 504   22.0     0.10959       41.93     0.573     6.794  89.3   2.54   2.31
# 505   19.0     0.04741       41.93     0.573     6.030  80.8   2.72   2.24
#
# ...

# %%
sns.displot(df['rainfall'])

# %%
sns.boxplot(df['n_hot_rooms'])
# Out:
# <Axes: ylabel='n_hot_rooms'>

# %% [markdown]
# def outliers():
#      q3=df['n_hot_rooms'].quantile(0.25)
#      q4=df['n_hot_rooms'].quantile(0.75)
#      iqr=q4-q3
#      lower_limit=q3-1.5*iqr
#      upper_limit=q4+1.5*iqr
#      return lower_limit,upper_limit
# limit=outliers()
# print(limit)
# new_df=df[(df['n_hot_rooms']>=lower_limit) & (df['n_hot_rooms']<=upper_limit)]
# new_df
# new_df.describe()
# print(len(new_df),len(df))

# %%
sns.boxplot(new_df['n_hot_rooms'])
# Out:
# <Axes: ylabel='n_hot_rooms'>

# %%
new_df.info()
new_df['n_hos_beds']=new_df['n_hos_beds'].fillna(new_df['n_hos_beds'].mean())
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 504 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        504 non-null    float64
#  1   crime_rate   504 non-null    float64
#  2   resid_area   504 non-null    float64
#  3   air_qual     504 non-null    float64
#  4   room_num     504 non-null    float64
#  5   age          504 non-null    float64
#  6   dist1        504 non-null    float64
#  7   dist2        504 non-null    float64
#  8   dist3        504 non-null    float64
#  9   dist4        504 non-null    float64
#  10  teachers     504 non-null    float64
#  11  poor_prop    504 non-null    float64
#  12  airport      504 non-null    object
#  13  n_hos_beds   504 non-null    float64
#  14  n_hot_rooms  504 non-null    float64
#  15  waterbody    350 non-null    object
#  16  rainfall     504 non-null    int64
#  17  bus_ter      504 non-null    object
# ...

# %%
new_df['waterbody']=new_df['waterbody'].fillna(new_df['waterbody'].mode()[0])
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 504 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        504 non-null    float64
#  1   crime_rate   504 non-null    float64
#  2   resid_area   504 non-null    float64
#  3   air_qual     504 non-null    float64
#  4   room_num     504 non-null    float64
#  5   age          504 non-null    float64
#  6   dist1        504 non-null    float64
#  7   dist2        504 non-null    float64
#  8   dist3        504 non-null    float64
#  9   dist4        504 non-null    float64
#  10  teachers     504 non-null    float64
#  11  poor_prop    504 non-null    float64
#  12  airport      504 non-null    object
#  13  n_hos_beds   504 non-null    float64
#  14  n_hot_rooms  504 non-null    float64
#  15  waterbody    504 non-null    object
#  16  rainfall     504 non-null    int64
#  17  bus_ter      504 non-null    object
# ...
